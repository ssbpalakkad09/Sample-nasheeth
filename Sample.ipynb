# %%
a=int(input("Enter 1st number : "))
b=int(input("Enter 2nd number : "))
c=a + b
print("The sum is " + str(c))
# Out:
# The sum is 60

# %% [markdown]
# printing a word

# %% [markdown]
# # Multiple line

# %%
print ("Hai")
# Out:
# Hai

# %%
a=(input("Enter a word : "))
b=a[::-1]
if a==b:
    print ("The word you entered is palindrom")
else :
    print ("It is not palindrome")
# Out:
# The word you entered is palindrom

# %%
a=20
b=30
print("First value is ", a)
print ("The number {} is second".format(b))
print("The value of first number is {a} and the second number is {b}".format(b="50",a="40")) #\ to print in next line
# Out:
# First value is  20
# The number 30 is second
# The value of first number is 40 and the second number is 50

# %% [markdown]
# string indexing

# %%
a="Good morning"
b="Have a nice day"
print (a+" "+b)
a.split()
# Out:
# Good morning Have a nice day
# ['Good', 'morning']

# %% [markdown]
# while loop

# %%
a=1
while a<5:
    print (a)
    a=a+1
# Out:
# 1
# 2
# 3
# 4

# %% [markdown]
# List

# %%
a=[10,20,30]
b=[50,60,70]
c=a+b
print(c)
c.append(90)
print(c)
c[2]=40
print(c)
c.remove(50)
print(c)
a.extend(b)
print(a)
c.reverse()
print(c)
c.sort()
print(c)
c.sort(reverse=True)
print(c)
print(c.count(20))
print("Malappuram".count("M"))
# Out:
# [10, 20, 30, 50, 60, 70]
# [10, 20, 30, 50, 60, 70, 90]
# [10, 20, 40, 50, 60, 70, 90]
# [10, 20, 40, 60, 70, 90]
# [10, 20, 30, 50, 60, 70]
# [90, 70, 60, 40, 20, 10]
# [10, 20, 40, 60, 70, 90]
# [90, 70, 60, 40, 20, 10]
# 1
# 1

# %%
a=["Welcome to", "SSB", "Malappuram"]
print(" ".join(a))
print(" ".join(a))
# Out:
# Welcome to SSB Malappuram
# Welcome to SSB Malappuram

# %%
a=("Welcome to SSB malappuram")
print(a.capitalize())
print(a.lower())
print(a.upper())
print(a.swapcase())
# Out:
# Welcome to ssb malappuram
# welcome to ssb malappuram
# WELCOME TO SSB MALAPPURAM
# wELCOME TO ssb MALAPPURAM

# %%
a=25.5
a=float(a)
print(a)
a=int(a)
print(a)
a=float(a)
print(a)
a=int(False)
print(a)
a=int(True)
print(a)
a=bool("Hi")
print(a)
a=bool("")
print(a)
b=24.5
print(bool(a))
# Out:
# 25.5
# 25
# 25.0
# 0
# 1
# True
# False
# False

# %%
def add():
    a=10
    b=20
    print(a+b)
add()
# Out:
# 30

# %%
def word(a):
    print("HI "*a)
word(5)
# Out:
# HI HI HI HI HI

# %%
def addn(a,b):
    c=a+b
    print("Sum =",c)
def sub(a,b):
    d=a-b
    print("Substraction = ",d)
a=int(input("1st Number : "))
b=int(input("2nd Number: "))
addn(a,b)
sub(a,b)
# Out:
# Sum = 63
# Substraction =  17

# %%
a=int(input("number "))
for i in range (1,11):
    print(a," * ",i," =", a*i)
# Out:
# 10  *  1  = 10
# 10  *  2  = 20
# 10  *  3  = 30
# 10  *  4  = 40
# 10  *  5  = 50
# 10  *  6  = 60
# 10  *  7  = 70
# 10  *  8  = 80
# 10  *  9  = 90
# 10  *  10  = 100

# %%
with open("Simp.txt", "w") as a:
    a.write("Hi")

# %%
with open("Simp.txt", "r") as a:  #can copy file path and paste it in open("path....")
    data=a.read()
print(data)
# Out:
# Hi

# %%
import os
file_names = os.listdir("D:\\Tech\\Rasiq")
print(file_names)
os.mkdir("Data")
os.rename("Simp.txt", "Data.txt")
# Out:
# ['Alarm.bat', 'Calc.py', 'Parrot-security-6.3.2_amd64.iso', 'Python.py', 'shutdown.py', 'Star.py', 'Test.py']

# %%
import datetime
print(datetime.datetime.now())
# Out:
# 2025-04-22 13:29:05.594946

# %%
import os
file_names=os.listdir("C:\\Users\\nashe\\Downloads")
for file_names in file_names:
    if ".pdf" in file_names:
        print (file_names)
# Out:
# 0-387-30808-3_3.pdf
# 1 KTU Curriculum 2024- V 22_LTM_240307_192712.pdf
# 1-s2.0-S0032591021009207-main.pdf
# 1-s2.0-S0048969721047537-main.pdf
# 1-s2.0-S2214799323000206-main.pdf
# 1.pdf
# 1._B._Tech_Academic_Calender__S2_S4_S6_S8_Jan_24-Jun_24_v3.pdf
# 10.1016@j.cep.2005.04.005.pdf
# 10.1515_ntrev-2018-0076.pdf
# 1114.pdf
# 12-6-182-370.pdf
# 1570106_2025-Perinthalmanna Murder.pdf
# 1570108_2025-Edavann PV Anvar press release.pdf
# 1723-1726.pdf
# 19 SPMR=====NR 18 GR 200 ( ALERT ).tif (1 page).pdf
# 1STYEARSYLLABUS_KTU_GROUPC-181-186.pdf
# 1STYEARSYLLABUS_KTU_GROUPC.pdf
# 2-Engineering-Properties-1-40.pdf
# 2. B.Tech Second Year Syllabus - 2020 Scheme.pdf
# 2015-Dr Radhai Sri- Manufacturing and Evaluation of Formulated Nutraceutical.pdf
# 202230_prod_MFGE303970_202230_50104.pdf
# 2024 scheme food chemistry S2.pdf
# 20240507_135939 (1).pdf
# 2050_SE_S1_Vegetable-Seed-Treatments.pdf
# 2193-8865-3-67.pdf
# 219_2023_a.pdf
# 2_ Chapter 2_1 (Dairy products and analogues).pdf
# ...

# %%
import pandas as pd
data = pd.read_csv("Test_file.csv")
data
# Out:
#      Name Class Office  Rank
# 0    Nash     A   kadn     3
# 1     dsd     F   dfsa     4
# 2    sjfn     w   dfnj     5
# 3  osaijd     r   sdfu     9
# 4  sdfgjk     f   iohe     6

# %%
import pandas as pd
data=pd.read_csv("students_data.csv")
data
data.describe()
# Out:
#        Marks_Math  Marks_Science  Marks_English  Attendance
# count   50.000000      50.000000      50.000000   50.000000
# mean    72.840000      70.120000      67.760000   72.740000
# std     17.917452      16.030125      15.871371   15.045251
# min     40.000000      41.000000      40.000000   51.000000
# 25%     59.250000      57.250000      58.000000   60.000000
# 50%     76.000000      73.000000      63.500000   72.000000
# 75%     87.000000      83.750000      80.250000   86.250000
# max    100.000000      95.000000     100.000000  100.000000

# %%
date=pd.read_excel("students_data.xlsx")
data
data.head()
# Out:
#                 Name  Marks_Math  Marks_Science  Marks_English Date_of_Birth  \
# 0        Debbie Diaz          62             45             58    2006-06-25
# 1    Brenda Robinson          65             71             41    2009-04-14
# 2     Gregory Morgan          77             46             54    2010-10-29
# 3        David Brown         100             58             78    2010-06-11
# 4     Lindsey Taylor          49             50             58    2012-10-03
# 5  Shannon Rodriguez          79             76             75    2012-05-14
# 6      John Caldwell          44             58             76    2013-03-07
# 7        Ashley Pena          77             55             67    2011-09-22
# 8         Ian Mendez          79             80             58    2013-04-08
# 9      Charles Grant          68             59             91    2006-11-14
#
#    Attendance
# 0          76
# 1          88
# 2          78
# 3          74
# 4          67
# 5          51
# ...

# %%
data[["Name","Attendance"]].to_excel("Students_Attendance.xlsx")

# %%
data[["Attendance", "Name"]].to_excel("Students_Attendance.xlsx")

# %%
data.columns.tolist()
# Out:
# ['Name',
#  'Marks_Math',
#  'Marks_Science',
#  'Marks_English',
#  'Date_of_Birth',
#  'Attendance']

# %%
data["Attendance"].value_counts()
# Out:
# Attendance
# 52     5
# 77     4
# 84     3
# 87     3
# 60     3
# 66     3
# 56     2
# 64     2
# 55     2
# 67     1
# 70     1
# 51     1
# 74     1
# 78     1
# 76     1
# 88     1
# 99     1
# 68     1
# 93     1
# 100    1
# 94     1
# 90     1
# 96     1
# 71     1
# 53     1
# 80     1
# 69     1
# 73     1
# 92     1
# 58     1
# 97     1
# 91     1
# Name: count, dtype: int64

# %%
data[data["Attendance"]>=90]
# Out:
#                Name  Marks_Math  Marks_Science  Marks_English Date_of_Birth  \
# 8        Ian Mendez          79             80             58    2013-04-08
# 12    Raymond Evans          99             54             44    2011-09-11
# 13    Charles Clark          87             65             81    2009-11-02
# 16     Diana Hurley          79             51             48    2013-02-04
# 17       Evan Owens          46             49             62    2008-01-04
# 22      Keith Smith          63             51             99    2008-12-29
# 37  Stephen Walters          74             86             64    2013-02-16
# 42    Michael Garza          75             79             59    2012-09-19
# 47    Wendy Hubbard          53             77             78    2007-09-02
#
#     Attendance
# 8           94
# 12         100
# 13          93
# 16          99
# 17          96
# 22          90
# 37          92
# 42          97
# 47          91

# %%
with pd.ExcelWriter("students_data.xlsx") as writer:
    data.describe().to_excel(writer, sheet_name="Attendance")
    data.sort_values(by="Marks_Math", ascending=False).to_excel(writer, sheet_name="Maths marks")

# %%
data.drop(["Attendance", "Marks_Math"], axis=1)
# Out:
#                     Name  Marks_Science  Marks_English Date_of_Birth
# 0            Debbie Diaz             45             58    2006-06-25
# 1        Brenda Robinson             71             41    2009-04-14
# 2         Gregory Morgan             46             54    2010-10-29
# 3            David Brown             58             78    2010-06-11
# 4         Lindsey Taylor             50             58    2012-10-03
# 5      Shannon Rodriguez             76             75    2012-05-14
# 6          John Caldwell             58             76    2013-03-07
# 7            Ashley Pena             55             67    2011-09-22
# 8             Ian Mendez             80             58    2013-04-08
# 9          Charles Grant             59             91    2006-11-14
# 10         Douglas Lewis             92             86    2009-12-10
# 11       Patrick Fleming             89            100    2008-03-27
# 12         Raymond Evans             54             44    2011-09-11
# ...

# %%
import os
import pandas as pd
file_path=os.path.join("data", "students_data.xlsx")
data=pd.read_excel(file_path)
data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 4
#       2 import pandas as pd
#       3 file_path=os.path.join("data", "students_data.xlsx")
# ----> 4 data=pd.read_excel(file_path)
#       5 data
#
# File c:\Users\nashe\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
# ...

# %%
data.iloc[:5,2:9]
# Out:
#    Marks_Science  Marks_English Date_of_Birth  Attendance
# 0             45             58    2006-06-25          76
# 1             71             41    2009-04-14          88
# 2             46             54    2010-10-29          78
# 3             58             78    2010-06-11          74
# 4             50             58    2012-10-03          67
